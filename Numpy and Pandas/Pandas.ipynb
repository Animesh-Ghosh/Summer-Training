# %%
import pandas as pd

data = pd.read_csv('../bike-share-project/data/NYC-CitiBike-2016.csv')

# %%
#Print first 5 rows
data.head()
#Enter integer n in argument to get first n rows
# Out:
#    tripduration          starttime           stoptime  start station id  \
# 0           839  1/1/2016 00:09:55  1/1/2016 00:23:54               532
# 1           686  1/1/2016 00:21:17  1/1/2016 00:32:44              3143
# 2           315  1/1/2016 00:33:11  1/1/2016 00:38:26              3164
# 3           739  1/1/2016 00:40:51  1/1/2016 00:53:11               223
# 4          1253  1/1/2016 00:44:16  1/1/2016 01:05:09               484
#
#        start station name  start station latitude  start station longitude  \
# 0         S 5 Pl & S 4 St               40.710451               -73.960876
# 1         5 Ave & E 78 St               40.776829               -73.963888
# 2  Columbus Ave & W 72 St               40.777057               -73.978985
# 3         W 13 St & 7 Ave               40.737815               -73.999947
# 4         W 44 St & 5 Ave               40.755003               -73.980144
#
#    end station id          end station name  end station latitude  \
# ...

# %%
data.dtypes
# Out:
# tripduration                 int64
# starttime                   object
# stoptime                    object
# start station id             int64
# start station name          object
# start station latitude     float64
# start station longitude    float64
# end station id               int64
# end station name            object
# end station latitude       float64
# end station longitude      float64
# bikeid                       int64
# usertype                    object
# birth year                 float64
# gender                       int64
# dtype: object

# %%
data['tripduration']
# Out:
# 0          839
# 1          686
# 2          315
# 3          739
# 4         1253
# 5          525
# 6          659
# 7          464
# 8          206
# 9          425
# 10         798
# 11         584
# 12         505
# 13        1431
# 14         673
# 15         541
# 16         191
# 17         835
# 18         788
# 19         598
# 20        1238
# 21         460
# 22        1407
# 23         282
# 24         213
# 25         984
# 26         312
# 27        1422
# 28         669
# 29         223
#           ...
# 276768     647
# 276769     292
# 276770     483
# 276771    2908
# 276772    1533
# 276773     168
# 276774    1740
# 276775    2120
# 276776    1348
# 276777    1848
# 276778    1023
# 276779     827
# 276780     698
# 276781      85
# 276782    1008
# 276783     344
# 276784     815
# 276785    1640
# 276786    1071
# 276787     664
# 276788     758
# 276789    1798
# 276790     701
# 276791     235
# 276792     561
# 276793     295
# 276794     277
# ...

# %%
type(data['tripduration'])
# Out:
# pandas.core.series.Series

# %%
data['tripduration'] / 60
# Out:
# 0         13.983333
# 1         11.433333
# 2          5.250000
# 3         12.316667
# 4         20.883333
# 5          8.750000
# 6         10.983333
# 7          7.733333
# 8          3.433333
# 9          7.083333
# 10        13.300000
# 11         9.733333
# 12         8.416667
# 13        23.850000
# 14        11.216667
# 15         9.016667
# 16         3.183333
# 17        13.916667
# 18        13.133333
# 19         9.966667
# 20        20.633333
# 21         7.666667
# 22        23.450000
# 23         4.700000
# 24         3.550000
# 25        16.400000
# 26         5.200000
# 27        23.700000
# 28        11.150000
# 29         3.716667
#             ...
# 276768    10.783333
# 276769     4.866667
# 276770     8.050000
# 276771    48.466667
# 276772    25.550000
# 276773     2.800000
# 276774    29.000000
# 276775    35.333333
# 276776    22.466667
# 276777    30.800000
# 276778    17.050000
# 276779    13.783333
# 276780    11.633333
# 276781     1.416667
# ...

# %%
# %matplotlib inline

# %%
data['tripduration'].plot(kind = 'hist')

# %%
data.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  2.767980e+05     276798.000000           276798.000000
# mean   9.487556e+02       1066.602945               40.737666
# std    6.231653e+03       1185.223048                0.024515
# min    6.100000e+01         72.000000               40.445350
# 25%    3.820000e+02        339.000000               40.720828
# 50%    6.310000e+02        465.000000               40.739017
# 75%    1.070000e+03       2003.000000               40.755003
# max    2.363758e+06       3440.000000               40.804213
#
#        start station longitude  end station id  end station latitude  \
# count            276798.000000   276798.000000         276798.000000
# mean                -73.986233     1049.084433             40.736912
# std                   0.016319     1174.303122              0.136310
# min                 -74.017134       72.000000              0.000000
# ...

# %% [markdown]
# ## Pandas
#
# ### DataFrame
#
# 2D structure that can take different types of values.
#
# We can create using lists and dictionaries alike.

# %%
import pandas as pd

# %%
data = [1,2,3,4,5]

pd.DataFrame(data)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
my_dict = {
    'name' : ['A', 'B', 'C'],
    'Age' : [20,30,40]
}

pd.DataFrame(my_dict)
# Out:
#   name  Age
# 0    A   20
# 1    B   30
# 2    C   40

# %%
my_dict = {
    'name' : ['A', 'B', 'C', 'D'],
    'Age' : [20,30,40]
}

pd.DataFrame(my_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-926ea46b5427> in <module>()
#       4 }
#       5
# ----> 6 pd.DataFrame(my_dict)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
# ...

# %%
#Read a file directly into a dataframe

df = pd.read_csv('../bike-share-project/examples/BayArea_Y3_trip_data.csv')
df
# Out:
#       Trip ID  Duration       Start Date  \
# 0      913481       459    9/1/2015 6:01
# 1      913538       535    9/1/2015 7:08
# 2      913693       445    9/1/2015 8:06
# 3      913697       330    9/1/2015 8:06
# 4      913707       970    9/1/2015 8:08
# 5      913748       252    9/1/2015 8:16
# 6      913778       539    9/1/2015 8:24
# 7      913838       577    9/1/2015 8:40
# 8      914013       689    9/1/2015 9:13
# 9      914126       860    9/1/2015 9:48
# 10     914176      1141   9/1/2015 10:10
# 11     914197      1292   9/1/2015 10:24
# 12     914240       234   9/1/2015 11:27
# 13     914385       478   9/1/2015 13:58
# 14     914393       158   9/1/2015 14:05
# 15     914415       160   9/1/2015 14:30
# 16     914435       185   9/1/2015 14:57
# 17     914481       864   9/1/2015 15:33
# 18     914512       774   9/1/2015 15:55
# 19     914593       470   9/1/2015 16:27
# 20     914608      1507   9/1/2015 16:34
# 21     914769       498   9/1/2015 17:15
# ...

# %%
df.columns
# Out:
# Index(['Trip ID', 'Duration', 'Start Date', 'Start Station', 'Start Terminal',
#        'End Date', 'End Station', 'End Terminal', 'Bike #', 'Subscriber Type',
#        'Zip Code'],
#       dtype='object')

# %%
#select duration
df['Duration']
# Out:
# 0         459
# 1         535
# 2         445
# 3         330
# 4         970
# 5         252
# 6         539
# 7         577
# 8         689
# 9         860
# 10       1141
# 11       1292
# 12        234
# 13        478
# 14        158
# 15        160
# 16        185
# 17        864
# 18        774
# 19        470
# 20       1507
# 21        498
# 22        296
# 23        746
# 24        636
# 25        370
# 26        653
# 27        287
# 28        909
# 29        212
#         ...
# 6269      350
# 6270      490
# 6271      507
# 6272      269
# 6273      490
# 6274      546
# 6275      313
# 6276      509
# 6277      486
# 6278      463
# 6279     1199
# 6280     1005
# 6281      453
# 6282      255
# 6283      908
# 6284      790
# 6285      572
# 6286    12248
# 6287      188
# 6288     3081
# 6289     1983
# 6290      587
# 6291      611
# 6292      471
# 6293      379
# 6294     1065
# 6295      461
# 6296      269
# 6297      318
# 6298      410
# ...

# %%
df['Duration'].dtype
# Out:
# dtype('int64')

# %%
df['Duration']/60
# Out:
# 0         7.650000
# 1         8.916667
# 2         7.416667
# 3         5.500000
# 4        16.166667
# 5         4.200000
# 6         8.983333
# 7         9.616667
# 8        11.483333
# 9        14.333333
# 10       19.016667
# 11       21.533333
# 12        3.900000
# 13        7.966667
# 14        2.633333
# 15        2.666667
# 16        3.083333
# 17       14.400000
# 18       12.900000
# 19        7.833333
# 20       25.116667
# 21        8.300000
# 22        4.933333
# 23       12.433333
# 24       10.600000
# 25        6.166667
# 26       10.883333
# 27        4.783333
# 28       15.150000
# 29        3.533333
#            ...
# 6269      5.833333
# 6270      8.166667
# 6271      8.450000
# 6272      4.483333
# 6273      8.166667
# 6274      9.100000
# 6275      5.216667
# 6276      8.483333
# 6277      8.100000
# 6278      7.716667
# 6279     19.983333
# 6280     16.750000
# 6281      7.550000
# 6282      4.250000
# 6283     15.133333
# 6284     13.166667
# ...

# %%
#Add a new column

df['Duration_mins'] = df['Duration']/60

# %%
df.columns
# Out:
# Index(['Trip ID', 'Duration', 'Start Date', 'Start Station', 'Start Terminal',
#        'End Date', 'End Station', 'End Terminal', 'Bike #', 'Subscriber Type',
#        'Zip Code', 'Duration_mins'],
#       dtype='object')

# %%
df.head()
# Out:
#    Trip ID  Duration     Start Date                             Start Station  \
# 0   913481       459  9/1/2015 6:01  San Francisco Caltrain (Townsend at 4th)
# 1   913538       535  9/1/2015 7:08      Harry Bridges Plaza (Ferry Building)
# 2   913693       445  9/1/2015 8:06  San Francisco Caltrain (Townsend at 4th)
# 3   913697       330  9/1/2015 8:06                    Embarcadero at Sansome
# 4   913707       970  9/1/2015 8:08  San Francisco Caltrain (Townsend at 4th)
#
#    Start Terminal       End Date               End Station  End Terminal  \
# 0              70  9/1/2015 6:09             2nd at Folsom            62
# 1              50  9/1/2015 7:17    Embarcadero at Sansome            60
# 2              70  9/1/2015 8:13             Howard at 2nd            63
# 3              60  9/1/2015 8:12          Davis at Jackson            42
# 4              70  9/1/2015 8:24  Commercial at Montgomery            45
#
#    Bike # Subscriber Type Zip Code  Duration_mins
# ...

# %%
df.head(10)
# Out:
#    Trip ID  Duration     Start Date                             Start Station  \
# 0   913481       459  9/1/2015 6:01  San Francisco Caltrain (Townsend at 4th)
# 1   913538       535  9/1/2015 7:08      Harry Bridges Plaza (Ferry Building)
# 2   913693       445  9/1/2015 8:06  San Francisco Caltrain (Townsend at 4th)
# 3   913697       330  9/1/2015 8:06                    Embarcadero at Sansome
# 4   913707       970  9/1/2015 8:08  San Francisco Caltrain (Townsend at 4th)
# 5   913748       252  9/1/2015 8:16                         Market at Sansome
# 6   913778       539  9/1/2015 8:24         Civic Center BART (7th at Market)
# 7   913838       577  9/1/2015 8:40                     Embarcadero at Bryant
# 8   914013       689  9/1/2015 9:13                       Golden Gate at Polk
# 9   914126       860  9/1/2015 9:48                           Townsend at 7th
#
#    Start Terminal        End Date  \
# 0              70   9/1/2015 6:09
# 1              50   9/1/2015 7:17
# ...

# %%
df.tail(10)
# Out:
#       Trip ID  Duration       Start Date  \
# 6289  1337619      1983  8/31/2016 12:21
# 6290  1337852       587  8/31/2016 16:26
# 6291  1337942       611  8/31/2016 16:59
# 6292  1337945       471  8/31/2016 17:00
# 6293  1337961       379  8/31/2016 17:06
# 6294  1338148      1065  8/31/2016 18:02
# 6295  1338274       461  8/31/2016 18:50
# 6296  1338306       269  8/31/2016 19:08
# 6297  1338317       318  8/31/2016 19:16
# 6298  1338342       410  8/31/2016 19:53
#
#                                  Start Station  Start Terminal  \
# 6289             Powell at Post (Union Square)              71
# 6290                   San Francisco City Hall              58
# 6291                     Embarcadero at Folsom              51
# 6292                             Howard at 2nd              63
# 6293                           Spear at Folsom              49
# 6294                           Clay at Battery              41
# ...

# %%
df.to_csv('new_example.csv')

# %%
#To get multiple columns, pass a list of columns
df[['Duration', 'Trip ID']]
# Out:
#       Duration  Trip ID
# 0          459   913481
# 1          535   913538
# 2          445   913693
# 3          330   913697
# 4          970   913707
# 5          252   913748
# 6          539   913778
# 7          577   913838
# 8          689   914013
# 9          860   914126
# 10        1141   914176
# 11        1292   914197
# 12         234   914240
# 13         478   914385
# 14         158   914393
# 15         160   914415
# 16         185   914435
# 17         864   914481
# 18         774   914512
# 19         470   914593
# 20        1507   914608
# 21         498   914769
# 22         296   914782
# 23         746   914809
# 24         636   914874
# 25         370   914894
# 26         653   914910
# 27         287   915223
# 28         909   915346
# 29         212   915455
# ...        ...      ...
# 6269       350  1336439
# 6270       490  1336457
# 6271       507  1336480
# 6272       269  1336493
# 6273       490  1336561
# 6274       546  1336584
# ...

# %%
df['Subscriber Type'].unique()
# Out:
# array(['Subscriber', 'Customer'], dtype=object)

# %%
df['Subscriber Type'].dtype
# Out:
# dtype('O')

# %%
#get types of all columns
df.dtypes
# Out:
# Trip ID              int64
# Duration             int64
# Start Date          object
# Start Station       object
# Start Terminal       int64
# End Date            object
# End Station         object
# End Terminal         int64
# Bike #               int64
# Subscriber Type     object
# Zip Code            object
# Duration_mins      float64
# dtype: object

# %% [markdown]
# ## Run and find issue from documentation
#
#     from datetime import datetime
#     df['Start Date'].astype(datetime)

# %%
#groupby

df.groupby('Subscriber Type').count()
# Out:
#                  Trip ID  Duration  Start Date  Start Station  Start Terminal  \
# Subscriber Type
# Customer             633       633         633            633             633
# Subscriber          5666      5666        5666           5666            5666
#
#                  End Date  End Station  End Terminal  Bike #  Zip Code  \
# Subscriber Type
# Customer              633          633           633     633       628
# Subscriber           5666         5666          5666    5666      5666
#
#                  Duration_mins
# Subscriber Type
# Customer                   633
# Subscriber                5666

# %%
type(df.groupby('Subscriber Type'))
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
df.groupby('Subscriber Type')['Duration_mins'].sum()
# Out:
# Subscriber Type
# Customer      34530.916667
# Subscriber    53898.583333
# Name: Duration_mins, dtype: float64

# %%
df.groupby('Subscriber Type')['Duration_mins'].mean()
# Out:
# Subscriber Type
# Customer      54.551211
# Subscriber     9.512634
# Name: Duration_mins, dtype: float64

# %%
df.groupby('Subscriber Type')['Duration_mins'].count()
# Out:
# Subscriber Type
# Customer       633
# Subscriber    5666
# Name: Duration_mins, dtype: int64

# %%
df.describe()
# Out:
#             Trip ID      Duration  Start Terminal  End Terminal       Bike #  \
# count  6.299000e+03   6299.000000     6299.000000   6299.000000  6299.000000
# mean   1.124184e+06    842.319416       58.775044     58.605493   415.371488
# std    1.234354e+05   2845.639502       16.296817     16.177400   166.936042
# min    9.134810e+05     63.000000        2.000000      2.000000     9.000000
# 25%    1.016132e+06    353.000000       50.000000     50.000000   315.000000
# 50%    1.122359e+06    516.000000       62.000000     62.000000   427.000000
# 75%    1.232132e+06    723.000000       70.000000     70.000000   541.000000
# max    1.338342e+06  77442.000000       91.000000     91.000000   878.000000
#
#        Duration_mins
# count    6299.000000
# mean       14.038657
# std        47.427325
# min         1.050000
# 25%         5.883333
# 50%         8.600000
# 75%        12.050000
# max      1290.700000

# %%
data = list(range(1, 101))
x = pd.DataFrame(data)
x.describe()
# Out:
#                 0
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000

# %%
graph = df['Duration_mins'].plot(kind = 'hist', bins = [0, 50, 100, 150, 200])
graph.set_xlabel('X')
graph.set_ylabel('Y')
graph.set_title('Graphity')
# Out:
# Text(0.5,1,'Graphity')

# %%
from datetime import datetime
type(df['Start Date'].astype(datetime)[0])
# Out:
# str

# %%
df
# Out:
#       Trip ID  Duration       Start Date  \
# 0      913481       459    9/1/2015 6:01
# 1      913538       535    9/1/2015 7:08
# 2      913693       445    9/1/2015 8:06
# 3      913697       330    9/1/2015 8:06
# 4      913707       970    9/1/2015 8:08
# 5      913748       252    9/1/2015 8:16
# 6      913778       539    9/1/2015 8:24
# 7      913838       577    9/1/2015 8:40
# 8      914013       689    9/1/2015 9:13
# 9      914126       860    9/1/2015 9:48
# 10     914176      1141   9/1/2015 10:10
# 11     914197      1292   9/1/2015 10:24
# 12     914240       234   9/1/2015 11:27
# 13     914385       478   9/1/2015 13:58
# 14     914393       158   9/1/2015 14:05
# 15     914415       160   9/1/2015 14:30
# 16     914435       185   9/1/2015 14:57
# 17     914481       864   9/1/2015 15:33
# 18     914512       774   9/1/2015 15:55
# 19     914593       470   9/1/2015 16:27
# 20     914608      1507   9/1/2015 16:34
# 21     914769       498   9/1/2015 17:15
# ...
