# %% [markdown]
# ## Convolutional Neural Networks
#
# ---
#
# Training a CNN to classify images from the CIFAR-10 database.
#
# ### 1. Load CIFAR-10 Database

# %%
import keras
from keras.datasets import cifar10

# load the pre-shuffled train and test data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# C:\Users\ANIMESH\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 62s 0us/step

# %% [markdown]
# ### 2. Visualize the Training Images

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Rescale the Images by Dividing Every Pixel in Every Image by 255

# %%
# rescale [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Breaking Dataset into Training, Testing, and Validation Sets

# %%
from keras.utils import np_utils

# one-hot encode the labels
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# break training set into training and validation sets
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# print shape of training set
print('x_train shape:', x_train.shape)

# print number of training, validation, and test images
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# x_train shape: (45000, 32, 32, 3)
# 45000 train samples
# 10000 test samples
# 5000 validation samples

# %% [markdown]
# ### 5. Defining the Model Architecture

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(500, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 64)          8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               512500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5010
# =================================================================
# Total params: 528,054
# Trainable params: 528,054
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compiling the Model

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Training the Model

# %%
from keras.callbacks import ModelCheckpoint   

# train the model
checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=32, epochs=100,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/100
#  - 56s - loss: 1.5871 - acc: 0.4268 - val_loss: 1.3468 - val_acc: 0.5290
#
# Epoch 00001: val_loss improved from inf to 1.34678, saving model to model.weights.best.hdf5
# Epoch 2/100
#  - 53s - loss: 1.2841 - acc: 0.5443 - val_loss: 1.1700 - val_acc: 0.5908
#
# Epoch 00002: val_loss improved from 1.34678 to 1.17003, saving model to model.weights.best.hdf5
# Epoch 3/100
#  - 55s - loss: 1.1681 - acc: 0.5880 - val_loss: 2.1741 - val_acc: 0.4166
#
# Epoch 00003: val_loss did not improve from 1.17003
# Epoch 4/100
#  - 54s - loss: 1.1013 - acc: 0.6142 - val_loss: 1.0988 - val_acc: 0.6282
#
# Epoch 00004: val_loss improved from 1.17003 to 1.09879, saving model to model.weights.best.hdf5
# Epoch 5/100
#  - 54s - loss: 1.0670 - acc: 0.6282 - val_loss: 1.0077 - val_acc: 0.6588
#
# Epoch 00005: val_loss improved from 1.09879 to 1.00773, saving model to model.weights.best.hdf5
# Epoch 6/100
#  - 54s - loss: 1.0445 - acc: 0.6396 - val_loss: 1.1198 - val_acc: 0.6180
#
# Epoch 00006: val_loss did not improve from 1.00773
# Epoch 7/100
#  - 53s - loss: 1.0284 - acc: 0.6452 - val_loss: 1.0054 - val_acc: 0.6670
#
# Epoch 00007: val_loss improved from 1.00773 to 1.00538, saving model to model.weights.best.hdf5
# Epoch 8/100
#  - 52s - loss: 1.0297 - acc: 0.6485 - val_loss: 1.0411 - val_acc: 0.6548
#
# Epoch 00008: val_loss did not improve from 1.00538
# Epoch 9/100
#  - 51s - loss: 1.0277 - acc: 0.6487 - val_loss: 1.0058 - val_acc: 0.6722
#
# Epoch 00009: val_loss did not improve from 1.00538
# Epoch 10/100
#  - 51s - loss: 1.0313 - acc: 0.6524 - val_loss: 1.5498 - val_acc: 0.5458
#
# Epoch 00010: val_loss did not improve from 1.00538
# Epoch 11/100
#  - 50s - loss: 1.0501 - acc: 0.6475 - val_loss: 1.0597 - val_acc: 0.6562
#
# Epoch 00011: val_loss did not improve from 1.00538
# Epoch 12/100
#  - 50s - loss: 1.0637 - acc: 0.6443 - val_loss: 1.1537 - val_acc: 0.6104
#
# Epoch 00012: val_loss did not improve from 1.00538
# Epoch 13/100
#  - 50s - loss: 1.0762 - acc: 0.6439 - val_loss: 1.1680 - val_acc: 0.6514
#
# Epoch 00013: val_loss did not improve from 1.00538
# Epoch 14/100
#  - 50s - loss: 1.0987 - acc: 0.6367 - val_loss: 1.1938 - val_acc: 0.6238
#
# Epoch 00014: val_loss did not improve from 1.00538
# Epoch 15/100
#  - 51s - loss: 1.1200 - acc: 0.6266 - val_loss: 1.1437 - val_acc: 0.6116
#
# Epoch 00015: val_loss did not improve from 1.00538
# Epoch 16/100
#  - 53s - loss: 1.1441 - acc: 0.6211 - val_loss: 1.1076 - val_acc: 0.6408
#
# Epoch 00016: val_loss did not improve from 1.00538
# Epoch 17/100
#  - 53s - loss: 1.1554 - acc: 0.6180 - val_loss: 1.2677 - val_acc: 0.6172
#
# Epoch 00017: val_loss did not improve from 1.00538
# Epoch 18/100
#  - 51s - loss: 1.1823 - acc: 0.6086 - val_loss: 1.0682 - val_acc: 0.6432
#
# Epoch 00018: val_loss did not improve from 1.00538
# Epoch 19/100
#  - 52s - loss: 1.2013 - acc: 0.6026 - val_loss: 1.1087 - val_acc: 0.6234
#
# Epoch 00019: val_loss did not improve from 1.00538
# Epoch 20/100
#  - 54s - loss: 1.2111 - acc: 0.5969 - val_loss: 1.0836 - val_acc: 0.6368
#
# Epoch 00020: val_loss did not improve from 1.00538
# Epoch 21/100
#  - 53s - loss: 1.2341 - acc: 0.5936 - val_loss: 1.2655 - val_acc: 0.5812
#
# Epoch 00021: val_loss did not improve from 1.00538
# Epoch 22/100
#  - 51s - loss: 1.2462 - acc: 0.5909 - val_loss: 1.1673 - val_acc: 0.5984
#
# Epoch 00022: val_loss did not improve from 1.00538
# Epoch 23/100
#  - 52s - loss: 1.2600 - acc: 0.5816 - val_loss: 1.7122 - val_acc: 0.5688
#
# Epoch 00023: val_loss did not improve from 1.00538
# Epoch 24/100
#  - 51s - loss: 1.2817 - acc: 0.5766 - val_loss: 1.2376 - val_acc: 0.6086
#
# Epoch 00024: val_loss did not improve from 1.00538
# Epoch 25/100
#  - 52s - loss: 1.2864 - acc: 0.5737 - val_loss: 1.1631 - val_acc: 0.6054
#
# Epoch 00025: val_loss did not improve from 1.00538
# Epoch 26/100
#  - 52s - loss: 1.2964 - acc: 0.5720 - val_loss: 1.7805 - val_acc: 0.4870
#
# Epoch 00026: val_loss did not improve from 1.00538
# Epoch 27/100
#  - 52s - loss: 1.3127 - acc: 0.5671 - val_loss: 1.2732 - val_acc: 0.5834
#
# Epoch 00027: val_loss did not improve from 1.00538
# Epoch 28/100
#  - 52s - loss: 1.3238 - acc: 0.5616 - val_loss: 1.7179 - val_acc: 0.5482
#
# Epoch 00028: val_loss did not improve from 1.00538
# Epoch 29/100
#  - 52s - loss: 1.3529 - acc: 0.5550 - val_loss: 1.2067 - val_acc: 0.5890
#
# Epoch 00029: val_loss did not improve from 1.00538
# Epoch 30/100
#  - 51s - loss: 1.3664 - acc: 0.5460 - val_loss: 1.6242 - val_acc: 0.5700
#
# Epoch 00030: val_loss did not improve from 1.00538
# Epoch 31/100
#  - 55s - loss: 1.3870 - acc: 0.5413 - val_loss: 1.2721 - val_acc: 0.5632
#
# Epoch 00031: val_loss did not improve from 1.00538
# Epoch 32/100
#  - 53s - loss: 1.3962 - acc: 0.5346 - val_loss: 1.1899 - val_acc: 0.6050
#
# Epoch 00032: val_loss did not improve from 1.00538
# Epoch 33/100
#  - 54s - loss: 1.4304 - acc: 0.5243 - val_loss: 1.4330 - val_acc: 0.5524
#
# Epoch 00033: val_loss did not improve from 1.00538
# Epoch 34/100
#  - 54s - loss: 1.4432 - acc: 0.5202 - val_loss: 1.2363 - val_acc: 0.5712
#
# Epoch 00034: val_loss did not improve from 1.00538
# Epoch 35/100
#  - 55s - loss: 1.4568 - acc: 0.5129 - val_loss: 1.5311 - val_acc: 0.5254
#
# Epoch 00035: val_loss did not improve from 1.00538
# Epoch 36/100
#  - 54s - loss: 1.4749 - acc: 0.5081 - val_loss: 2.1029 - val_acc: 0.4554
#
# Epoch 00036: val_loss did not improve from 1.00538
# Epoch 37/100
#  - 55s - loss: 1.4841 - acc: 0.5065 - val_loss: 1.1639 - val_acc: 0.5948
#
# Epoch 00037: val_loss did not improve from 1.00538
# Epoch 38/100
#  - 53s - loss: 1.4872 - acc: 0.4970 - val_loss: 2.4565 - val_acc: 0.4142
#
# Epoch 00038: val_loss did not improve from 1.00538
# Epoch 39/100
#  - 45s - loss: 1.5041 - acc: 0.4912 - val_loss: 1.2574 - val_acc: 0.5774
#
# Epoch 00039: val_loss did not improve from 1.00538
# Epoch 40/100
#  - 53s - loss: 1.5237 - acc: 0.4862 - val_loss: 1.5428 - val_acc: 0.4680
#
# Epoch 00040: val_loss did not improve from 1.00538
# Epoch 41/100
#  - 52s - loss: 1.5318 - acc: 0.4876 - val_loss: 1.2362 - val_acc: 0.5932
#
# Epoch 00041: val_loss did not improve from 1.00538
# Epoch 42/100
#  - 53s - loss: 1.5329 - acc: 0.4828 - val_loss: 1.3299 - val_acc: 0.5740
#
# Epoch 00042: val_loss did not improve from 1.00538
# Epoch 43/100
#  - 55s - loss: 1.5436 - acc: 0.4812 - val_loss: 1.4196 - val_acc: 0.5508
#
# Epoch 00043: val_loss did not improve from 1.00538
# Epoch 44/100
#  - 52s - loss: 1.5515 - acc: 0.4764 - val_loss: 1.5223 - val_acc: 0.4280
#
# Epoch 00044: val_loss did not improve from 1.00538
# Epoch 45/100
#  - 52s - loss: 1.5600 - acc: 0.4755 - val_loss: 1.3706 - val_acc: 0.5288
#
# Epoch 00045: val_loss did not improve from 1.00538
# Epoch 46/100
#  - 56s - loss: 1.5753 - acc: 0.4676 - val_loss: 1.4357 - val_acc: 0.5066
#
# Epoch 00046: val_loss did not improve from 1.00538
# Epoch 47/100
#  - 51s - loss: 1.5636 - acc: 0.4679 - val_loss: 1.3324 - val_acc: 0.5526
#
# Epoch 00047: val_loss did not improve from 1.00538
# Epoch 48/100
#  - 52s - loss: 1.5884 - acc: 0.4607 - val_loss: 1.2899 - val_acc: 0.5442
#
# Epoch 00048: val_loss did not improve from 1.00538
# Epoch 49/100
#  - 52s - loss: 1.6063 - acc: 0.4513 - val_loss: 1.6810 - val_acc: 0.4842
#
# Epoch 00049: val_loss did not improve from 1.00538
# Epoch 50/100
#  - 53s - loss: 1.6456 - acc: 0.4425 - val_loss: 1.4559 - val_acc: 0.5222
#
# Epoch 00050: val_loss did not improve from 1.00538
# Epoch 51/100
#  - 53s - loss: 1.6632 - acc: 0.4334 - val_loss: 2.4449 - val_acc: 0.3466
#
# Epoch 00051: val_loss did not improve from 1.00538
# Epoch 52/100
#  - 51s - loss: 1.6643 - acc: 0.4324 - val_loss: 1.6237 - val_acc: 0.4600
#
# Epoch 00052: val_loss did not improve from 1.00538
# Epoch 53/100
#  - 49s - loss: 1.6743 - acc: 0.4289 - val_loss: 2.0469 - val_acc: 0.4360
#
# Epoch 00053: val_loss did not improve from 1.00538
# Epoch 54/100
#  - 49s - loss: 1.6926 - acc: 0.4199 - val_loss: 1.5195 - val_acc: 0.4738
#
# Epoch 00054: val_loss did not improve from 1.00538
# Epoch 55/100
#  - 52s - loss: 1.6878 - acc: 0.4212 - val_loss: 1.5044 - val_acc: 0.4460
#
# Epoch 00055: val_loss did not improve from 1.00538
# Epoch 56/100
#  - 48s - loss: 1.7128 - acc: 0.4145 - val_loss: 1.5867 - val_acc: 0.4522
#
# Epoch 00056: val_loss did not improve from 1.00538
# Epoch 57/100
#  - 50s - loss: 1.7240 - acc: 0.4129 - val_loss: 1.5298 - val_acc: 0.4654
#
# Epoch 00057: val_loss did not improve from 1.00538
# Epoch 58/100
#  - 49s - loss: 1.7260 - acc: 0.4054 - val_loss: 1.5407 - val_acc: 0.4764
#
# Epoch 00058: val_loss did not improve from 1.00538
# Epoch 59/100
#  - 51s - loss: 1.7415 - acc: 0.4005 - val_loss: 1.8134 - val_acc: 0.3028
#
# Epoch 00059: val_loss did not improve from 1.00538
# Epoch 60/100
#  - 51s - loss: 1.7287 - acc: 0.4045 - val_loss: 1.9400 - val_acc: 0.3506
#
# Epoch 00060: val_loss did not improve from 1.00538
# Epoch 61/100
#  - 53s - loss: 1.7332 - acc: 0.4000 - val_loss: 1.8271 - val_acc: 0.3496
#
# Epoch 00061: val_loss did not improve from 1.00538
# Epoch 62/100
#  - 53s - loss: 1.7714 - acc: 0.3847 - val_loss: 1.5752 - val_acc: 0.4162
#
# Epoch 00062: val_loss did not improve from 1.00538
# Epoch 63/100
#  - 51s - loss: 1.7756 - acc: 0.3808 - val_loss: 6.2171 - val_acc: 0.2212
#
# Epoch 00063: val_loss did not improve from 1.00538
# Epoch 64/100
#  - 52s - loss: 1.7817 - acc: 0.3838 - val_loss: 1.8593 - val_acc: 0.4034
#
# Epoch 00064: val_loss did not improve from 1.00538
# Epoch 65/100
#  - 53s - loss: 1.7761 - acc: 0.3802 - val_loss: 1.5276 - val_acc: 0.4558
#
# Epoch 00065: val_loss did not improve from 1.00538
# Epoch 66/100
#  - 49s - loss: 1.7768 - acc: 0.3798 - val_loss: 1.6449 - val_acc: 0.4040
#
# Epoch 00066: val_loss did not improve from 1.00538
# Epoch 67/100
#  - 46s - loss: 1.7698 - acc: 0.3809 - val_loss: 1.6006 - val_acc: 0.4308
#
# Epoch 00067: val_loss did not improve from 1.00538
# Epoch 68/100
#  - 45s - loss: 1.7840 - acc: 0.3778 - val_loss: 1.5107 - val_acc: 0.4620
#
# Epoch 00068: val_loss did not improve from 1.00538
# Epoch 69/100
#  - 45s - loss: 1.7811 - acc: 0.3777 - val_loss: 4.5620 - val_acc: 0.2578
#
# Epoch 00069: val_loss did not improve from 1.00538
# Epoch 70/100
#  - 47s - loss: 1.7961 - acc: 0.3755 - val_loss: 1.6042 - val_acc: 0.4114
#
# Epoch 00070: val_loss did not improve from 1.00538
# Epoch 71/100
#  - 47s - loss: 1.8131 - acc: 0.3665 - val_loss: 1.5662 - val_acc: 0.4296
#
# Epoch 00071: val_loss did not improve from 1.00538
# Epoch 72/100
#  - 47s - loss: 1.8189 - acc: 0.3615 - val_loss: 1.6156 - val_acc: 0.3998
#
# Epoch 00072: val_loss did not improve from 1.00538
# Epoch 73/100
#  - 47s - loss: 1.8142 - acc: 0.3602 - val_loss: 1.5292 - val_acc: 0.4162
#
# Epoch 00073: val_loss did not improve from 1.00538
# Epoch 74/100
#  - 47s - loss: 1.8230 - acc: 0.3615 - val_loss: 1.6486 - val_acc: 0.4258
#
# Epoch 00074: val_loss did not improve from 1.00538
# Epoch 75/100
#  - 47s - loss: 1.8297 - acc: 0.3555 - val_loss: 1.5614 - val_acc: 0.4480
#
# Epoch 00075: val_loss did not improve from 1.00538
# Epoch 76/100
#  - 46s - loss: 1.8418 - acc: 0.3469 - val_loss: 1.6414 - val_acc: 0.4274
#
# Epoch 00076: val_loss did not improve from 1.00538
# Epoch 77/100
#  - 47s - loss: 1.8530 - acc: 0.3457 - val_loss: 1.7359 - val_acc: 0.4030
#
# Epoch 00077: val_loss did not improve from 1.00538
# Epoch 78/100
#  - 50s - loss: 1.8377 - acc: 0.3501 - val_loss: 1.5217 - val_acc: 0.4480
#
# Epoch 00078: val_loss did not improve from 1.00538
# Epoch 79/100
#  - 49s - loss: 1.8440 - acc: 0.3479 - val_loss: 1.6469 - val_acc: 0.4010
#
# Epoch 00079: val_loss did not improve from 1.00538
# Epoch 80/100
#  - 49s - loss: 1.8601 - acc: 0.3388 - val_loss: 1.8028 - val_acc: 0.3388
#
# Epoch 00080: val_loss did not improve from 1.00538
# Epoch 81/100
#  - 49s - loss: 1.8678 - acc: 0.3350 - val_loss: 2.1574 - val_acc: 0.2722
#
# Epoch 00081: val_loss did not improve from 1.00538
# Epoch 82/100
#  - 48s - loss: 1.8801 - acc: 0.3258 - val_loss: 1.7158 - val_acc: 0.3426
#
# Epoch 00082: val_loss did not improve from 1.00538
# Epoch 83/100
#  - 49s - loss: 1.8728 - acc: 0.3253 - val_loss: 1.7648 - val_acc: 0.3386
#
# Epoch 00083: val_loss did not improve from 1.00538
# Epoch 84/100
#  - 50s - loss: 1.8620 - acc: 0.3336 - val_loss: 2.2267 - val_acc: 0.2950
#
# Epoch 00084: val_loss did not improve from 1.00538
# Epoch 85/100
#  - 49s - loss: 1.8708 - acc: 0.3307 - val_loss: 2.6121 - val_acc: 0.2778
#
# Epoch 00085: val_loss did not improve from 1.00538
# Epoch 86/100
#  - 50s - loss: 1.8783 - acc: 0.3242 - val_loss: 2.2913 - val_acc: 0.2876
#
# Epoch 00086: val_loss did not improve from 1.00538
# Epoch 87/100
#  - 50s - loss: 1.8769 - acc: 0.3236 - val_loss: 1.6409 - val_acc: 0.3828
#
# Epoch 00087: val_loss did not improve from 1.00538
# Epoch 88/100
#  - 49s - loss: 1.8778 - acc: 0.3209 - val_loss: 1.7562 - val_acc: 0.3336
#
# Epoch 00088: val_loss did not improve from 1.00538
# Epoch 89/100
#  - 49s - loss: 1.8840 - acc: 0.3205 - val_loss: 2.0370 - val_acc: 0.2908
#
# Epoch 00089: val_loss did not improve from 1.00538
# Epoch 90/100
#  - 51s - loss: 1.8970 - acc: 0.3150 - val_loss: 1.9051 - val_acc: 0.2876
#
# Epoch 00090: val_loss did not improve from 1.00538
# Epoch 91/100
#  - 49s - loss: 1.8923 - acc: 0.3133 - val_loss: 1.7363 - val_acc: 0.3846
#
# Epoch 00091: val_loss did not improve from 1.00538
# Epoch 92/100
#  - 44s - loss: 1.9001 - acc: 0.3103 - val_loss: 1.7748 - val_acc: 0.3560
#
# Epoch 00092: val_loss did not improve from 1.00538
# Epoch 93/100
#  - 48s - loss: 1.8998 - acc: 0.3151 - val_loss: 1.6460 - val_acc: 0.3904
#
# Epoch 00093: val_loss did not improve from 1.00538
# Epoch 94/100
#  - 50s - loss: 1.8981 - acc: 0.3117 - val_loss: 1.6561 - val_acc: 0.3602
#
# Epoch 00094: val_loss did not improve from 1.00538
# Epoch 95/100
#  - 49s - loss: 1.9156 - acc: 0.3062 - val_loss: 1.7397 - val_acc: 0.3654
#
# Epoch 00095: val_loss did not improve from 1.00538
# Epoch 96/100
#  - 50s - loss: 1.9205 - acc: 0.3061 - val_loss: 1.8011 - val_acc: 0.3688
#
# Epoch 00096: val_loss did not improve from 1.00538
# Epoch 97/100
#  - 50s - loss: 1.9237 - acc: 0.2992 - val_loss: 1.6825 - val_acc: 0.3834
#
# Epoch 00097: val_loss did not improve from 1.00538
# Epoch 98/100
#  - 51s - loss: 1.9286 - acc: 0.3037 - val_loss: 1.6865 - val_acc: 0.3960
#
# Epoch 00098: val_loss did not improve from 1.00538
# Epoch 99/100
#  - 51s - loss: 1.9271 - acc: 0.2979 - val_loss: 1.7431 - val_acc: 0.3726
#
# Epoch 00099: val_loss did not improve from 1.00538
# Epoch 100/100
#  - 50s - loss: 1.9233 - acc: 0.2989 - val_loss: 1.8807 - val_acc: 0.3202
#
# Epoch 00100: val_loss did not improve from 1.00538

# %% [markdown]
# ### 8. Loading Model with the Best Validation Accuracy

# %%
# load the weights that yielded the best validation accuracy
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Calculating Classification Accuracy on Test Set

# %%
# evaluate and print test accuracy
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.6649

# %% [markdown]
# ### 10. Visualization
#
# *Note:* **Visualization code not mine; got it from another source.**

# %%
# get predictions on the test set
y_hat = model.predict(x_test)

# define text labels (source: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot a random sample of test images, their predicted labels, and ground truth
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
